# %% [markdown]
# # IMDB Movie Review Sentiment Analysis Using CNN

# %%
# Importing the dataset
from keras.datasets import imdb

# Parameters: Using top 20K words; no skipping; no initial max length filter
VOCAB_SIZE = 20000
SKIP_COUNT = 0
MAX_LENGTH = None

# Loading dataset
print("Loading the IMDB dataset...")
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=VOCAB_SIZE, skip_top=SKIP_COUNT, maxlen=MAX_LENGTH)
print("Dataset loaded!")
# Out:
# Loading the IMDB dataset...
# Dataset loaded!

# %%
print("Size of training set :", len(train_data))
print("Size of test set     :", len(test_data))
# Out:
# Size of training set : 25000
# Size of test set     : 25000

# %%
print("Sample training example:")
print(train_data[3])
print("Label:")
print(train_labels[3])
# Out:
# Sample training example:
# [1, 4, 18609, 16085, 33, 2804, 4, 2040, 432, 111, 153, 103, 4, 1494, 13, 70, 131, 67, 11, 61, 15305, 744, 35, 3715, 761, 61, 5766, 452, 9214, 4, 985, 7, 2, 59, 166, 4, 105, 216, 1239, 41, 1797, 9, 15, 7, 35, 744, 2413, 31, 8, 4, 687, 23, 4, 2, 7339, 6, 3693, 42, 38, 39, 121, 59, 456, 10, 10, 7, 265, 12, 575, 111, 153, 159, 59, 16, 1447, 21, 25, 586, 482, 39, 4, 96, 59, 716, 12, 4, 172, 65, 9, 579, 11, 6004, 4, 1615, 5, 2, 7, 5168, 17, 13, 7064, 12, 19, 6, 464, 31, 314, 11, 2, 6, 719, 605, 11, 8, 202, 27, 310, 4, 3772, 3501, 8, 2722, 58, 10, 10, 537, 2116, 180, 40, 14, 413, 173, 7, 263, 112, 37, 152, 377, 4, 537, 263, 846, 579, 178, 54, 75, 71, 476, 36, 413, 263, 2504, 182, 5, 17, 75, 2306, 922, 36, 279, 131, 2895, 17, 2867, 42, 17, 35, 921, 18435, 192, 5, 1219, 3890, 19, 2, 217, 4122, 1710, 537, 2, 1236, 5, 736, 10, 10, 61, 403, 9, 2, 40, 61, 4494, 5, 27, 4494, 159, 90, 263, 2311, 4319, 309, 8, 178, 5, 82, 4319, 4, 65, 15, 9225, 145, 143, 5122, 12, 7039, 537, 746, 537, 537, 15, 7979, 4, 18665, 594, 7, 5168, 94, 9096, 3987, 15242, 11, 2, 4, 538, 7, 1795, 246, 2, 9, 10161, 11, 635, 14, 9, 51, 408, 12, 94, 318, 1382, 12, 47, 6, 2683, 936, 5, 6307, 10197, 19, 49, 7, 4, 1885, 13699, 1118, 25, 80, 126, 842, 10, 10, 2, 18223, 4726, 27, 4494, 11, 1550, 3633, 159, 27, 341, 29, 2733, 19, 4185, 173, 7, 90, 16376, 8, 30, 11, 4, 1784, 86, 1117, 8, 3261, 46, 11, 2, 21, 29, 9, 2841, 23, 4, 1010, 2, 793, 6, 13699, 1386, 1830, 10, 10, 246, 50, 9, 6, 2750, 1944, 746, 90, 29, 16376, 8, 124, 4, 882, 4, 882, 496, 27, 2, 2213, 537, 121, 127, 1219, 130, 5, 29, 494, 8, 124, 4, 882, 496, 4, 341, 7, 27, 846, 10, 10, 29, 9, 1906, 8, 97, 6, 236, 11120, 1311, 8, 4, 2, 7, 31, 7, 2, 91, 2, 3987, 70, 4, 882, 30, 579, 42, 9, 12, 32, 11, 537, 10, 10, 11, 14, 65, 44, 537, 75, 11876, 1775, 3353, 12716, 1846, 4, 11286, 7, 154, 5, 4, 518, 53, 13243, 11286, 7, 3211, 882, 11, 399, 38, 75, 257, 3807, 19, 18223, 17, 29, 456, 4, 65, 7, 27, 205, 113, 10, 10, 2, 4, 2, 10359, 9, 242, 4, 91, 1202, 11377, 5, 2070, 307, 22, 7, 5168, 126, 93, 40, 18223, 13, 188, 1076, 3222, 19, 4, 13465, 7, 2348, 537, 23, 53, 537, 21, 82, 40, 18223, 13, 2, 14, 280, 13, 219, 4, 2, 431, 758, 859, 4, 953, 1052, 12283, 7, 5991, 5, 94, 40, 25, 238, 60, 2, 4, 15812, 804, 2, 7, 4, 9941, 132, 8, 67, 6, 22, 15, 9, 283, 8, 5168, 14, 31, 9, 242, 955, 48, 25, 279, 2, 23, 12, 1685, 195, 25, 238, 60, 796, 13713, 4, 671, 7, 2804, 5, 4, 559, 154, 888, 7, 726, 50, 26, 49, 7008, 15, 566, 30, 579, 21, 64, 2574]
# Label:
# 1

# %%
# Create mapping for words and convert sample review to text
word_to_index = imdb.get_word_index()

index_to_word = dict ( [(idx, word) for (word, idx) in word_to_index.items()] )
english_review = ' '.join ( [index_to_word.get(idx-3, '?') for idx in train_data[3]] )

print("Earlier training example in English:")
print(english_review)
# Out:
# Earlier training example in English:
# ? the scots excel at storytelling the traditional sort many years after the event i can still see in my mind's eye an elderly lady my friend's mother retelling the battle of ? she makes the characters come alive her passion is that of an eye witness one to the events on the ? heath a mile or so from where she lives br br of course it happened many years before she was born but you wouldn't guess from the way she tells it the same story is told in bars the length and ? of scotland as i discussed it with a friend one night in ? a local cut in to give his version the discussion continued to closing time br br stories passed down like this become part of our being who doesn't remember the stories our parents told us when we were children they become our invisible world and as we grow older they maybe still serve as inspiration or as an emotional reservoir fact and fiction blend with ? role models warning stories ? magic and mystery br br my name is ? like my grandfather and his grandfather before him our protagonist introduces himself to us and also introduces the story that stretches back through generations it produces stories within stories stories that evoke the impenetrable wonder of scotland its rugged mountains shrouded in ? the stuff of legend yet ? is rooted in reality this is what gives it its special charm it has a rough beauty and authenticity tempered with some of the finest gaelic singing you will ever hear br br ? angus visits his grandfather in hospital shortly before his death he burns with frustration part of him yearns to be in the twenty first century to hang out in ? but he is raised on the western ? among a gaelic speaking community br br yet there is a deeper conflict within him he yearns to know the truth the truth behind his ? ancient stories where does fiction end and he wants to know the truth behind the death of his parents br br he is pulled to make a last fateful journey to the ? of one of ? most ? mountains can the truth be told or is it all in stories br br in this story about stories we revisit bloody battles poisoned lovers the folklore of old and the sometimes more treacherous folklore of accepted truth in doing so we each connect with angus as he lives the story of his own life br br ? the ? pinnacle is probably the most honest unpretentious and genuinely beautiful film of scotland ever made like angus i got slightly annoyed with the pretext of hanging stories on more stories but also like angus i ? this once i saw the ? picture ' forget the box office pastiche of braveheart and its like you might even ? the justly famous ? of the wicker man to see a film that is true to scotland this one is probably unique if you maybe ? on it deeply enough you might even re evaluate the power of storytelling and the age old question of whether there are some truths that cannot be told but only experienced

# %%
import random

# Display a few reviews
num_samples = 5
sample_indices = random.sample(range(len(train_data)), num_samples)

for i in sample_indices:
    # Convert the review back to English, only include words present in the mapping
    english_review = ' '.join([index_to_word[idx-3] for idx in train_data[i] if (idx-3) in index_to_word])
    sentiment = "Positive" if train_labels[i] == 1 else "Negative"
    print(f"Review (Index {i}):")
    print(english_review)
    print("Sentiment:", sentiment)
    print("-"*80)
# Out:
# Review (Index 10131):
# i saw this pilot when it was first shown and i'm sure countless spirit fans hate it because like batman the green etc it took the character in the direction of camp but i evidently never got enough of batman because i thought it was entertaining in some of the same ways as that show there are two parts that stay with me first when partner has been fatally wounded and he makes a dramatic speech about how he always stood for the law and the exact letter of it then he says something like boy was i stupid which is his way of telling denny to become a vigilante instead which he does though the tv batman kind then there's the scene where he tries to seduce the villainess into letting him go by kissing her but she isn't fooled because he's too honest to kiss her convincingly this was a great example of camp that was also by both the actor and actress
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Review (Index 18164):
# part of what was so great about the classic looney tunes cartoons was their and how they weren't afraid to do anything that they wanted in this case marvin the martian has an assignment to bring back an sure enough he comes across bugs bunny who warns of a mutiny on the part of dog after marvin finally traps bugs by means of an strait jacket bugs has more stuff planned for the voyage back to mars what i mean is if you thought that it was a major change in the solar system when they stripped pluto of its planet status then you ain't seen nothing yet yes the hasty hare goes all out how they buy products in outer space is probably beyond most people but the point here i mean hare is to have fun and believe me you definitely will after all a little space out never hurt anyone
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Review (Index 3367):
# only children below the age of 12 should be allowed to see this film the rest of us should take a book player or just take a nice nap to endure the experience of this event this can be best summed up as a blown up tv movie being distributed into theaters children will want to see this film and they will like and be amused by the movie
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Review (Index 10559):
# did sandra yes she must have know we would still be here for her some nine years later br br see it if you haven't again if you have see her live while you can
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Review (Index 9539):
# dream quest was a surprisingly good movie there were some noticeable goofs but that can be expected in a movie like this that was made in such a short time i did not feel any urge to fast forward during the movie and i found it pretty entertaining it gets kind of silly at times but overall i recommend it they probably used up all the glitter in the nearby stores and some of the costume designs were pretty good
# Sentiment: Positive
# --------------------------------------------------------------------------------

# %%
# Verifying vocabulary range
max_index = max ( [max(review) for review in train_data] )

print("VOCAB_SIZE          =", VOCAB_SIZE)
print("Max index of a word =", max_index)
# Out:
# VOCAB_SIZE          = 20000
# Max index of a word = 19999

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Visualization: Review length
review_lengths = [len(review) for review in train_data]
plt.figure(figsize=(10,5))
plt.hist(review_lengths, bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Review Lengths (Training Set)')
plt.xlabel('Review Length')
plt.ylabel('Number of Reviews')
plt.show()

# %%
# Visualization: Class distribution in the training set
unique, counts = np.unique(train_labels, return_counts=True)
plt.figure(figsize=(6,4))
plt.bar(unique, counts, color=['salmon', 'lightgreen'])
plt.xticks(unique, ['Negative', 'Positive'])
plt.title('Class Distribution in Training Data')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.show()

# %% [markdown]
# ###Preparing the Dataset

# %%
# Find and store the length of the longest review in the dataset
max_train_length = max (len(review) for review in train_data)
max_test_length = max (len(review) for review in test_data)

max_length = max(max_train_length, max_test_length)
print("Maximum length of a review in dataset:", max_length)
# Out:
# Maximum length of a review in dataset: 2494

# %%
from keras.preprocessing.sequence import pad_sequences

# Pad each review in the dataset till their length = max_length
print("Padding the reviews...")
train_data = pad_sequences (train_data, maxlen=max_length)
test_data = pad_sequences (test_data, maxlen=max_length)

print("Shape of train_data =", train_data.shape)
print("Shape of test_data  =", test_data.shape)
# Out:
# Padding the reviews...
# Shape of train_data = (25000, 2494)
# Shape of test_data  = (25000, 2494)

# %% [markdown]
# ###Building CNN Model

# %%
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Dropout, Flatten, GlobalAveragePooling1D
from keras.regularizers import l2

model = Sequential()
model.add(Embedding(input_dim = VOCAB_SIZE,
                    output_dim = 128,
                    input_shape=(MAX_LENGTH,)))
model.add(Conv1D(filters = 128,
                 kernel_size = 3,
                 strides = 1,
                 padding = 'valid',
                 activation = 'relu',
                ))
model.add(MaxPooling1D(pool_size = 7))
model.add(GlobalMaxPooling1D())
model.add(Dense(units = 32,
                activation = 'relu'))
model.add(Dense(units = 1,
                activation = 'sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, None, 128)           │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, None, 128)           │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, None, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_1               │ (None, 128)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,613,441 (9.97 MB)
#  Trainable params: 2,613,441 (9.97 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['acc'])

# %% [markdown]
# ###Training CNN Model

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau, TerminateOnNaN

callback_list = [
                 ModelCheckpoint(
                     filepath = '/content/best_CNNmodel.keras',
                     monitor = 'val_acc',
                     verbose = 1,
                     save_best_only = True,
                     save_weights_only = False,
                     mode = 'max',
                     save_freq='epoch'
                 ),

                 EarlyStopping(
                    monitor = 'val_acc',
                    patience = 20,
                    verbose = 1,
                    mode = 'max',
                    baseline = 0.5,
                    restore_best_weights = True
                 ),

                 ReduceLROnPlateau(
                     monitor = 'val_loss',
                     factor = 0.2,
                     patience = 5,
                     verbose = 1,
                     mode = 'min',
                     cooldown = 1,
                     min_lr = 0
                 ),

                 TerminateOnNaN()
]

# %%
history = model.fit(train_data,
                    train_labels,
                    epochs = 100,
                    batch_size = 64,
                    verbose = 1,
                    callbacks = callback_list,
                    validation_split = 0.10,
                    shuffle = True)
# Out:
# Epoch 1/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.7028 - loss: 0.5517
# Epoch 1: val_acc improved from -inf to 0.88800, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - acc: 0.7031 - loss: 0.5513 - val_acc: 0.8880 - val_loss: 0.2790 - learning_rate: 0.0010
# Epoch 2/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9291 - loss: 0.1895
# Epoch 2: val_acc improved from 0.88800 to 0.89760, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 0.9291 - loss: 0.1895 - val_acc: 0.8976 - val_loss: 0.2493 - learning_rate: 0.0010
# Epoch 3/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.9847 - loss: 0.0610
# Epoch 3: val_acc improved from 0.89760 to 0.90200, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - acc: 0.9847 - loss: 0.0609 - val_acc: 0.9020 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 4/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9988 - loss: 0.0122
# Epoch 4: val_acc improved from 0.90200 to 0.90280, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - acc: 0.9988 - loss: 0.0122 - val_acc: 0.9028 - val_loss: 0.3148 - learning_rate: 0.0010
# Epoch 5/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9999 - loss: 0.0022
# Epoch 5: val_acc did not improve from 0.90280
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - acc: 0.9999 - loss: 0.0022 - val_acc: 0.9028 - val_loss: 0.3357 - learning_rate: 0.0010
# Epoch 6/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 9.1592e-04
# Epoch 6: val_acc improved from 0.90280 to 0.90360, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 9.1583e-04 - val_acc: 0.9036 - val_loss: 0.3492 - learning_rate: 0.0010
# Epoch 7/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 4.7940e-04
# Epoch 7: val_acc did not improve from 0.90360
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 4.7926e-04 - val_acc: 0.9036 - val_loss: 0.3628 - learning_rate: 0.0010
# Epoch 8/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 3.1831e-04
# Epoch 8: val_acc improved from 0.90360 to 0.90400, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - acc: 1.0000 - loss: 3.1832e-04 - val_acc: 0.9040 - val_loss: 0.3651 - learning_rate: 2.0000e-04
# Epoch 9/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 2.9824e-04
# Epoch 9: val_acc did not improve from 0.90400
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - acc: 1.0000 - loss: 2.9823e-04 - val_acc: 0.9036 - val_loss: 0.3682 - learning_rate: 2.0000e-04
# Epoch 10/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 2.6716e-04
# Epoch 10: val_acc improved from 0.90400 to 0.90600, saving model to /content/best_CNNmodel.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - acc: 1.0000 - loss: 2.6717e-04 - val_acc: 0.9060 - val_loss: 0.3713 - learning_rate: 2.0000e-04
# Epoch 11/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 2.4457e-04
# Epoch 11: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 2.4456e-04 - val_acc: 0.9060 - val_loss: 0.3749 - learning_rate: 2.0000e-04
# Epoch 12/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 2.1806e-04
# Epoch 12: val_acc did not improve from 0.90600
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 2.1806e-04 - val_acc: 0.9060 - val_loss: 0.3789 - learning_rate: 2.0000e-04
# Epoch 13/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 2.0068e-04
# Epoch 13: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - acc: 1.0000 - loss: 2.0066e-04 - val_acc: 0.9052 - val_loss: 0.3798 - learning_rate: 4.0000e-05
# Epoch 14/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.9236e-04
# Epoch 14: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 1.9237e-04 - val_acc: 0.9044 - val_loss: 0.3809 - learning_rate: 4.0000e-05
# Epoch 15/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.8693e-04
# Epoch 15: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 1.8693e-04 - val_acc: 0.9044 - val_loss: 0.3821 - learning_rate: 4.0000e-05
# Epoch 16/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.8445e-04
# Epoch 16: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 1.8443e-04 - val_acc: 0.9056 - val_loss: 0.3834 - learning_rate: 4.0000e-05
# Epoch 17/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.7096e-04
# Epoch 17: val_acc did not improve from 0.90600
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 1.7097e-04 - val_acc: 0.9060 - val_loss: 0.3849 - learning_rate: 4.0000e-05
# Epoch 18/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.6843e-04
# Epoch 18: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - acc: 1.0000 - loss: 1.6842e-04 - val_acc: 0.9060 - val_loss: 0.3854 - learning_rate: 8.0000e-06
# Epoch 19/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.6642e-04
# Epoch 19: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 1.6641e-04 - val_acc: 0.9052 - val_loss: 0.3858 - learning_rate: 8.0000e-06
# Epoch 20/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.6543e-04
# Epoch 20: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - acc: 1.0000 - loss: 1.6542e-04 - val_acc: 0.9052 - val_loss: 0.3863 - learning_rate: 8.0000e-06
# Epoch 21/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.6314e-04
# Epoch 21: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - acc: 1.0000 - loss: 1.6312e-04 - val_acc: 0.9052 - val_loss: 0.3869 - learning_rate: 8.0000e-06
# Epoch 22/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 1.0000 - loss: 1.5570e-04
# Epoch 22: val_acc did not improve from 0.90600
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - acc: 1.0000 - loss: 1.5571e-04 - val_acc: 0.9044 - val_loss: 0.3877 - learning_rate: 8.0000e-06
# Epoch 23/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.5519e-04
# Epoch 23: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 1.5519e-04 - val_acc: 0.9048 - val_loss: 0.3878 - learning_rate: 1.6000e-06
# Epoch 24/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.5284e-04
# Epoch 24: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - acc: 1.0000 - loss: 1.5284e-04 - val_acc: 0.9048 - val_loss: 0.3880 - learning_rate: 1.6000e-06
# Epoch 25/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.4854e-04
# Epoch 25: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - acc: 1.0000 - loss: 1.4855e-04 - val_acc: 0.9048 - val_loss: 0.3883 - learning_rate: 1.6000e-06
# Epoch 26/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.5219e-04
# Epoch 26: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 1.5219e-04 - val_acc: 0.9048 - val_loss: 0.3885 - learning_rate: 1.6000e-06
# Epoch 27/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.4719e-04
# Epoch 27: val_acc did not improve from 0.90600
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - acc: 1.0000 - loss: 1.4721e-04 - val_acc: 0.9048 - val_loss: 0.3888 - learning_rate: 1.6000e-06
# Epoch 28/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.4744e-04
# Epoch 28: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - acc: 1.0000 - loss: 1.4746e-04 - val_acc: 0.9048 - val_loss: 0.3889 - learning_rate: 3.2000e-07
# Epoch 29/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.5110e-04
# Epoch 29: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - acc: 1.0000 - loss: 1.5109e-04 - val_acc: 0.9048 - val_loss: 0.3890 - learning_rate: 3.2000e-07
# Epoch 30/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 1.4928e-04
# Epoch 30: val_acc did not improve from 0.90600
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - acc: 1.0000 - loss: 1.4928e-04 - val_acc: 0.9048 - val_loss: 0.3891 - learning_rate: 3.2000e-07
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
print("Best Validation Accuracy =", max(history.history['val_acc'])*100)
print("Best Training Accuracy =", max(history.history['acc'])*100)
# Out:
# Best Validation Accuracy = 90.6000018119812
# Best Training Accuracy = 100.0

# %% [markdown]
# ### Plotting the results

# %%
import matplotlib.pyplot as plt

#Plot CNN Accuracy
train_acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(1, len(train_acc) + 1)

plt.plot(epochs, train_acc, 'r-', label='Training accuracy')
plt.plot(epochs, val_acc, 'g-', label='Validation accuracy')
plt.title('Training & Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
#Plot CNN Loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, train_loss, 'r-', label="Training loss")
plt.plot(epochs, val_loss, 'g-', label='Validation loss')
plt.title('Training & Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Testing Model

# %%
test_metrics = model.evaluate(test_data, test_labels)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - acc: 0.8947 - loss: 0.3799

# %%
test_accuracy = test_metrics[1]
test_loss = test_metrics[0]

print("Test Accuracy :", test_accuracy)
# Out:
# Test Accuracy : 0.8973199725151062

# %%
# Confusion Matrix on the test set
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_predictions = model.predict(test_data, verbose=0)
test_predictions_binary = (test_predictions > 0.5).astype(int)

cm = confusion_matrix(test_labels, test_predictions_binary)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Negative', 'Positive'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix on Test Data')
plt.show()

# %%
# Loading the best CNN model and using it to predict the Sentiment class of input moview review
from keras.models import load_model
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences

model = load_model ('/content/best_CNNmodel.keras')

print("Type a movie review :")
input_review = str(input())

word_to_index = imdb.get_word_index()
print("Processing input...")
tokenized_review = [word.lower() for word in input_review.split()]
text_indices = [word_to_index[word]+3 for word in tokenized_review if word in word_to_index.keys()]
model_input = [text_indices]
model_input = pad_sequences (model_input, maxlen = 2494)

print("Running the model with input...")
prediction = model.predict(model_input, verbose = 0)

if (prediction>0.5):
    print("Prediction: Positive")
else:
    print("Prediction: Negative")
# Out:
# Type a movie review :
# This was a terrible movie. The plot was predictable, the characters were dull, and the dialogue was cringeworthy. I regret wasting my time watching it.
# Processing input...
# Running the model with input...
# Prediction: Negative
